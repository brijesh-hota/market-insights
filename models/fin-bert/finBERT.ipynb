# %% [markdown]
# ## finBERT Model
# This notebook is used to run the finBERT model where we can add sentiment to the stocks_news.csv file.

# %% [markdown]
# ### 1. Installing transformers

# %%
# %%capture
# %pip install 'transformers[torch]' torchvision torchaudio

# %% [markdown]
# ### 2. Importing the libraries
# Folowing commands are uploaded in the code file
# *   transformers[`torch`]: This installs the Hugging Face Transformers library, which is a popular library for Natural Language Processing (NLP) tasks. The [`torch`] part specifies that the installation should include the PyTorch version of the library, which is needed if you plan to use it with PyTorch.
# *   torchvision: This installs torchvision, which is a PyTorch library that provides datasets, transforms, and models for computer vision tasks.
# *   torchaudio: This installs torchaudio, which is a PyTorch library for audio processing.
# *   The %%capture magic command ensures that the output of the installation process is not displayed in the notebook cell.

# %%
from transformers import BertForSequenceClassification, BertTokenizer, pipeline
import torch
import torch.nn.functional as F
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# 2023-07-30 00:41:40.827529: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### 3. Model and Tokenizer Initialization
# `BertForSequenceClassification`: This is a class from the transformers library that represents a pre-trained BERT model fine-tuned for sequence classification tasks. In your case, the specific model being used is 'ProsusAI/finbert', which is a BERT model pre-trained on financial data and fine-tuned for sentiment analysis of financial news headlines.
#
# `BertTokenizer`: This is a class from the transformers library that represents a BERT tokenizer. The tokenizer is responsible for converting text data into numerical tokens that can be understood by the BERT model. It segments text into subwords (or words) and converts them into numerical representations suitable for feeding into the BERT model.
#
# By using from_pretrained() for both BertForSequenceClassification and BertTokenizer, the code is loading the pre-trained 'ProsusAI/finbert' model and its tokenizer. This allows you to use the pre-trained model for sentiment analysis on financial news headlines.

# %%
model = BertForSequenceClassification.from_pretrained('ProsusAI/finbert')
tokenizer = BertTokenizer.from_pretrained('ProsusAI/finbert')

model.save_pretrained("../..")
tokenizer.save_pretrained("../..")

# %%
stocks_news = pd.read_csv('../finbert_stocks_input.csv')
stocks_news.head(10)
# Out:
#   related    datetime                                           headline  \
# 0    AAPL  1672719360  Apple downgraded to Neutral from Outperform at...
# 1    AAPL  1672806957  China's 2025 Strategy Emerges As Top 2023 Inve...
# 2    AAPL  1672892100  BMW Takes Cues From Apple With Radical Interio...
# 3    AAPL  1672988286         Covid chaos in China and a new Swiss haven
# 4    AAPL  1673293335      Apple's VP services Stern to depart - Insider
# 5    AAPL  1673398441  Apple to begin making in-house screens from 20...
# 6    AAPL  1673414160  Apple Is Moving More of Its Supply Chain In-Ho...
# 7    AAPL  1673496480  Taiwan Semiconductor stock rises after chipmak...
# 8    AAPL  1673591031  Apple chief Tim Cook takes over 40% pay cut, s...
# 9    AAPL  1673928420  Foxconn Replaces iPhone Business Chief After T...
#
#           id        source                                            summary  \
# 0  118097919    Thefly.com  Looking for stock market analysis and research...
# 1  118110299  SeekingAlpha  The most important investment story of 2023 wi...
# 2  118133082         Yahoo  (Bloomberg) -- BMW AG’s latest prototype could...
# 3  118167357         Yahoo  This is Kenji from Hong Kong, where the schedu...
# 4  118194379       Reuters  Apple Inc's vice president of services, Peter ...
# 5  118194376       Reuters  Apple Inc is planning to start using its own c...
# 6  118224930   MarketWatch  Apple’s apparent desire to move more of its co...
# 7  118222444   MarketWatch  Contract chipmaker Taiwan Semiconductor Manufa...
# 8  118232127         Yahoo  Pay cut based on ‘shareholder feedback, Apple’...
# 9  118286413         Yahoo  (Bloomberg) -- Key Apple Inc. manufacturing pa...
#
#                                                  url datetime_norm  \
# 0  https://finnhub.io/api/news?id=c94bafbd39d76d2...    2023-01-03
# 1  https://finnhub.io/api/news?id=f6acfb521bd94a6...    2023-01-04
# 2  https://finnhub.io/api/news?id=60dae185ca4d6d6...    2023-01-05
# 3  https://finnhub.io/api/news?id=e3cb80be9a64b4f...    2023-01-06
# 4  https://finnhub.io/api/news?id=576e97b88e07030...    2023-01-09
# 5  https://finnhub.io/api/news?id=f6aa021fdc3dc7a...    2023-01-10
# 6  https://finnhub.io/api/news?id=616aff14a647bd2...    2023-01-11
# 7  https://finnhub.io/api/news?id=cd04aa27af0e266...    2023-01-12
# 8  https://finnhub.io/api/news?id=bc3b35bd469962a...    2023-01-13
# 9  https://finnhub.io/api/news?id=d5aefc49ae150f9...    2023-01-17
#
#          Open        High         Low       Close   Adj Close     Volume
# 0  130.279999  130.899994  124.169998  125.070000  124.706833  112117500
# 1  126.889999  128.660004  125.080002  126.360001  125.993095   89113600
# 2  127.129997  127.769997  124.760002  125.019997  124.656982   80962700
# 3  126.010002  130.289993  124.889999  129.619995  129.243622   87754700
# 4  130.470001  133.410004  129.889999  130.149994  129.772079   70790800
# 5  130.259995  131.259995  128.119995  130.729996  130.350403   63896200
# 6  131.250000  133.509995  130.460007  133.490005  133.102386   69458900
# 7  133.880005  134.259995  131.440002  133.410004  133.022614   71379600
# 8  132.029999  134.919998  131.660004  134.759995  134.368698   57809700
# 9  134.830002  137.289993  134.130005  135.940002  135.545273   63646600

# %% [markdown]
# ### 4. Stock News FinBERT Model Prediction
# Here, we perform the operations using the PyTorch. The `headline` and `summary` is combined to form one single entity called `news_description`.

# %%
print(len(stocks_news))
# Out:
# 638

# %%
stocks_sentiment = stocks_news.copy()

stocks_sentiment.head(10)
# Out:
#   related    datetime                                           headline  \
# 0    AAPL  1672719360  Apple downgraded to Neutral from Outperform at...
# 1    AAPL  1672806957  China's 2025 Strategy Emerges As Top 2023 Inve...
# 2    AAPL  1672892100  BMW Takes Cues From Apple With Radical Interio...
# 3    AAPL  1672988286         Covid chaos in China and a new Swiss haven
# 4    AAPL  1673293335      Apple's VP services Stern to depart - Insider
# 5    AAPL  1673398441  Apple to begin making in-house screens from 20...
# 6    AAPL  1673414160  Apple Is Moving More of Its Supply Chain In-Ho...
# 7    AAPL  1673496480  Taiwan Semiconductor stock rises after chipmak...
# 8    AAPL  1673591031  Apple chief Tim Cook takes over 40% pay cut, s...
# 9    AAPL  1673928420  Foxconn Replaces iPhone Business Chief After T...
#
#           id        source                                            summary  \
# 0  118097919    Thefly.com  Looking for stock market analysis and research...
# 1  118110299  SeekingAlpha  The most important investment story of 2023 wi...
# 2  118133082         Yahoo  (Bloomberg) -- BMW AG’s latest prototype could...
# 3  118167357         Yahoo  This is Kenji from Hong Kong, where the schedu...
# 4  118194379       Reuters  Apple Inc's vice president of services, Peter ...
# 5  118194376       Reuters  Apple Inc is planning to start using its own c...
# 6  118224930   MarketWatch  Apple’s apparent desire to move more of its co...
# 7  118222444   MarketWatch  Contract chipmaker Taiwan Semiconductor Manufa...
# 8  118232127         Yahoo  Pay cut based on ‘shareholder feedback, Apple’...
# 9  118286413         Yahoo  (Bloomberg) -- Key Apple Inc. manufacturing pa...
#
#                                                  url datetime_norm  \
# 0  https://finnhub.io/api/news?id=c94bafbd39d76d2...    2023-01-03
# 1  https://finnhub.io/api/news?id=f6acfb521bd94a6...    2023-01-04
# 2  https://finnhub.io/api/news?id=60dae185ca4d6d6...    2023-01-05
# 3  https://finnhub.io/api/news?id=e3cb80be9a64b4f...    2023-01-06
# 4  https://finnhub.io/api/news?id=576e97b88e07030...    2023-01-09
# 5  https://finnhub.io/api/news?id=f6aa021fdc3dc7a...    2023-01-10
# 6  https://finnhub.io/api/news?id=616aff14a647bd2...    2023-01-11
# 7  https://finnhub.io/api/news?id=cd04aa27af0e266...    2023-01-12
# 8  https://finnhub.io/api/news?id=bc3b35bd469962a...    2023-01-13
# 9  https://finnhub.io/api/news?id=d5aefc49ae150f9...    2023-01-17
#
#          Open        High         Low       Close   Adj Close     Volume
# 0  130.279999  130.899994  124.169998  125.070000  124.706833  112117500
# 1  126.889999  128.660004  125.080002  126.360001  125.993095   89113600
# 2  127.129997  127.769997  124.760002  125.019997  124.656982   80962700
# 3  126.010002  130.289993  124.889999  129.619995  129.243622   87754700
# 4  130.470001  133.410004  129.889999  130.149994  129.772079   70790800
# 5  130.259995  131.259995  128.119995  130.729996  130.350403   63896200
# 6  131.250000  133.509995  130.460007  133.490005  133.102386   69458900
# 7  133.880005  134.259995  131.440002  133.410004  133.022614   71379600
# 8  132.029999  134.919998  131.660004  134.759995  134.368698   57809700
# 9  134.830002  137.289993  134.130005  135.940002  135.545273   63646600

# %%
print(stocks_sentiment['headline'].isnull().sum())
print(len(stocks_sentiment['headline']))
# Out:
# 0
# 638

# %%
stock_sentiment_predictor = pipeline(task='sentiment-analysis', model=model, tokenizer=tokenizer)

# Get a list of headlines from the DataFrame
stock_headline = stocks_sentiment['headline'].tolist()

# Use the sentiment_predictor pipeline to predict sentiments for all headlines
stock_predictions = stock_sentiment_predictor(stock_headline)
# print(predictions)
print(len(stock_predictions))

# Extract the predicted sentiment labels and sentiment scores using list comprehensions
sentiments = [pred['label'] for pred in stock_predictions]
scores = [round(pred['score'], 3) for pred in stock_predictions]
# Out:
# Xformers is not installed correctly. If you want to use memory_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.
# 638

# %%
print(stock_predictions)
# Out:
# [{'label': 'negative', 'score': 0.5127232074737549}, {'label': 'positive', 'score': 0.7960140705108643}, {'label': 'neutral', 'score': 0.8397179841995239}, {'label': 'neutral', 'score': 0.7734225392341614}, {'label': 'negative', 'score': 0.9159166812896729}, {'label': 'neutral', 'score': 0.8729947209358215}, {'label': 'negative', 'score': 0.9399288892745972}, {'label': 'negative', 'score': 0.9666069746017456}, {'label': 'negative', 'score': 0.962792158126831}, {'label': 'negative', 'score': 0.6591130495071411}, {'label': 'positive', 'score': 0.9440958499908447}, {'label': 'neutral', 'score': 0.8667579293251038}, {'label': 'neutral', 'score': 0.9506423473358154}, {'label': 'positive', 'score': 0.8969438076019287}, {'label': 'neutral', 'score': 0.5101176500320435}, {'label': 'positive', 'score': 0.40891119837760925}, {'label': 'neutral', 'score': 0.8587100505828857}, {'label': 'neutral', 'score': 0.8877654075622559}, {'label': 'neutral', 'score': 0.8271477818489075}, {'label': 'neutral', 'score': 0.9011924266815186}, {'label': 'neutral', 'score': 0.8157338500022888}, {'label': 'positive', 'score': 0.7931687235832214}, {'label': 'neutral', 'score': 0.761631429195404}, {'label': 'negative', 'score': 0.9517546892166138}, {'label': 'neutral', 'score': 0.8832506537437439}, {'label': 'negative', 'score': 0.9355558156967163}, {'label': 'negative', 'score': 0.4970712959766388}, {'label': 'neutral', 'score': 0.9310728311538696}, {'label': 'positive', 'score': 0.7855215072631836}, {'label': 'neutral', 'score': 0.9352532625198364}, {'label': 'negative', 'score': 0.4173952341079712}, {'label': 'positive', 'score': 0.7443580627441406}, {'label': 'neutral', 'score': 0.8012456893920898}, {'label': 'neutral', 'score': 0.6972998380661011}, {'label': 'positive', 'score': 0.8189326524734497}, {'label': 'positive', 'score': 0.534907877445221}, {'label': 'neutral', 'score': 0.9304600358009338}, {'label': 'negative', 'score': 0.7278069257736206}, {'label': 'neutral', 'score': 0.8629104495048523}, {'label': 'positive', 'score': 0.7693461179733276}, {'label': 'neutral', 'score': 0.9125550985336304}, {'label': 'neutral', 'score': 0.7533712983131409}, {'label': 'positive', 'score': 0.5724903345108032}, {'label': 'neutral', 'score': 0.5896313190460205}, {'label': 'neutral', 'score': 0.9148641228675842}, {'label': 'neutral', 'score': 0.8786604404449463}, {'label': 'neutral', 'score': 0.9190059304237366}, {'label': 'neutral', 'score': 0.919601559638977}, {'label': 'neutral', 'score': 0.5269796252250671}, {'label': 'positive', 'score': 0.574866533279419}, {'label': 'neutral', 'score': 0.9016037583351135}, {'label': 'positive', 'score': 0.6439743041992188}, {'label': 'positive', 'score': 0.682993471622467}, {'label': 'neutral', 'score': 0.8118298053741455}, {'label': 'positive', 'score': 0.6222471594810486}, {'label': 'neutral', 'score': 0.8687074184417725}, {'label': 'neutral', 'score': 0.9231273531913757}, {'label': 'negative', 'score': 0.8074004650115967}, {'label': 'neutral', 'score': 0.901691198348999}, {'label': 'neutral', 'score': 0.9193418025970459}, {'label': 'positive', 'score': 0.9579771161079407}, {'label': 'neutral', 'score': 0.708211362361908}, {'label': 'neutral', 'score': 0.7751373052597046}, {'label': 'neutral', 'score': 0.8504075407981873}, {'label': 'negative', 'score': 0.958625853061676}, {'label': 'negative', 'score': 0.9728355407714844}, {'label': 'negative', 'score': 0.9621989130973816}, {'label': 'neutral', 'score': 0.9199742078781128}, {'label': 'neutral', 'score': 0.9193418025970459}, {'label': 'positive', 'score': 0.6901756525039673}, {'label': 'positive', 'score': 0.8361016511917114}, {'label': 'positive', 'score': 0.9409568905830383}, {'label': 'neutral', 'score': 0.8846560716629028}, {'label': 'neutral', 'score': 0.43221408128738403}, {'label': 'neutral', 'score': 0.8269303441047668}, {'label': 'neutral', 'score': 0.919601559638977}, {'label': 'neutral', 'score': 0.937709629535675}, {'label': 'positive', 'score': 0.66270589828491 ...

# %%
# Add the predicted_sentiment and sentiment_score as new columns to the DataFrame
stocks_sentiment['sentiment'] = sentiments
stocks_sentiment['score'] = scores

# %%
stocks_sentiment.head(20)
# Out:
#    related    datetime                                           headline  \
# 0     AAPL  1672719360  Apple downgraded to Neutral from Outperform at...
# 1     AAPL  1672806957  China's 2025 Strategy Emerges As Top 2023 Inve...
# 2     AAPL  1672892100  BMW Takes Cues From Apple With Radical Interio...
# 3     AAPL  1672988286         Covid chaos in China and a new Swiss haven
# 4     AAPL  1673293335      Apple's VP services Stern to depart - Insider
# 5     AAPL  1673398441  Apple to begin making in-house screens from 20...
# 6     AAPL  1673414160  Apple Is Moving More of Its Supply Chain In-Ho...
# 7     AAPL  1673496480  Taiwan Semiconductor stock rises after chipmak...
# 8     AAPL  1673591031  Apple chief Tim Cook takes over 40% pay cut, s...
# 9     AAPL  1673928420  Foxconn Replaces iPhone Business Chief After T...
# 10    AAPL  1674016098  Apple Gets a Boost in India as Chinese Supplie...
# 11    AAPL  1674115526  Stocks making the biggest moves before the bel...
# 12    AAPL  1674209160  89% of Warren Buffett's Secret Portfolio Is In...
# 13    AAPL  1674456005  Apple targeting to raise India production shar...
# 14    AAPL  1674547200  Will Tesla Stock Recover To $150? Yes, $200 By...
# 15    AAPL  1674622843  Apple beefs up smartphone services in ‘silent ...
# 16    AAPL  1674718320  How Apple's Ability To Pivot Is A Key Part Of ...
# 17    AAPL  1674858096  Why This May Be A 'Life Changing' Market Rally...
# 18    AAPL  1675053289                        Qualcomm: Apple Risk Fading
# 19    AAPL  1675139468                 CoreCard: Investing For The Future
#
#            id        source  \
# 0   118097919    Thefly.com
# 1   118110299  SeekingAlpha
# 2   118133082         Yahoo
# 3   118167357         Yahoo
# 4   118194379       Reuters
# 5   118194376       Reuters
# 6   118224930   MarketWatch
# 7   118222444   MarketWatch
# 8   118232127         Yahoo
# 9   118286413         Yahoo
# 10  118300126         Yahoo
# 11  118317678          CNBC
# 12  118329870         Yahoo
# 13  118353000       Reuters
# 14  118354965  SeekingAlpha
# 15  118363771         Yahoo
# 16  118378043  SeekingAlpha
# 17  118384355         Yahoo
# 18  118397920  SeekingAlpha
# 19  118402050  SeekingAlpha
#
#                                               summary  \
# 0   Looking for stock market analysis and research...
# 1   The most important investment story of 2023 wi...
# 2   (Bloomberg) -- BMW AG’s latest prototype could...
# 3   This is Kenji from Hong Kong, where the schedu...
# 4   Apple Inc's vice president of services, Peter ...
# 5   Apple Inc is planning to start using its own c...
# 6   Apple’s apparent desire to move more of its co...
# 7   Contract chipmaker Taiwan Semiconductor Manufa...
# 8   Pay cut based on ‘shareholder feedback, Apple’...
# 9   (Bloomberg) -- Key Apple Inc. manufacturing pa...
# 10  (Bloomberg) -- More than a dozen of Apple Inc....
# 11  These are the stocks posting the largest moves...
# 12  The Oracle of Omaha has a hidden $5.9 billion ...
# 13  Apple Inc wants India to account for up to 25%...
# 14  Tesla's share price is down more than 60% in t...
# 15  Apple is taking steps to separate its mobile o...
# 16  Part of Appleâs success has always been its ...
# 17  Apple earnings and the Fed meeting loom, but d...
# 18  Qualcomm has multiple paths to growth while in...
# 19  CoreCard has made investments to boost growth ...
#
#                                                   url datetime_norm  \
# 0   https://finnhub.io/api/news?id=c94bafbd39d76d2...    2023-01-03
# 1   https://finnhub.io/api/news?id=f6acfb521bd94a6...    2023-01-04
# 2   https://finnhub.io/api/news?id=60dae185ca4d6d6...    2023-01-05
# 3   https://finnhub.io/api/news?id=e3cb80be9a64b4f...    2023-01-06
# 4   https://finnhub.io/api/news?id=576e97b88e07030...    2023-01-09
# 5   https://finnhub.io/api/news?id=f6aa021fdc3dc7a...    2023-01-10
# 6   https://finnhub.io/api/news?id=616aff14a647bd2...    2023-01-11
# 7   https://finnhub.io/api/news?id=cd04aa27af0e266...    2023-01-12
# 8   https://finnhub.io/api/news?id=bc3b35bd469962a...    2023-01-13
# 9   https://finnhub.io/api/news?id=d5aefc49ae150f9...    2023-01-17
# 10  https://finnhub.io/api/news?id=aa01c18074ec2a3...    2023-01-18
# 11  https://finnhub.io/api/news?id=ac000fa4c273bb1...    2023-01-19
# 12  https://finnhub.io/api/news?id=b664f60ba7b68b2...    2023-01-20
# 13  https://finnhub.io/api/news?id=20f78dd893ee5e3...    2023-01-23
# 14  https://finnhub.io/api/news?id=2666ebf62cffd77...    2023-01-24
# 15  https://finnhub.io/api/news?id=c898db7350a3c3a...    2023-01-25
# 16  https://finnhub.io/api/news?id=a206170611c0add...    2023-01-26
# 17  https://finnhub.io/api/news?id=a4cc79f1c3d8bc2...    2023-01-27
# 18  https://finnhub.io/api/news?id=ae1aa37c0a479ff...    2023-01-30
# 19  https://finnhub.io/api/news?id=22713c3f6d3e7c5...    2023-01-31
#
#           Open        High         Low       Close   Adj Close     Volume  \
# 0   130.279999  130.899994  124.169998  125.070000  124.706833  112117500
# 1   126.889999  128.660004  125.080002  126.360001  125.993095   89113600
# 2   127.129997  127.769997  124.760002  125.019997  124.656982   80962700
# 3   126.010002  130.289993  124.889999  129.619995  129.243622   87754700
# 4   130.470001  133.410004  129.889999  130.149994  129.772079   70790800
# 5   130.259995  131.259995  128.119995  130.729996  130.350403   63896200
# 6   131.250000  133.509995  130.460007  133.490005  133.102386   69458900
# 7   133.880005  134.259995  131.440002  133.410004  133.022614   71379600
# 8   132.029999  134.919998  131.660004  134.759995  134.368698   57809700
# 9   134.830002  137.289993  134.130005  135.940002  135.545273   63646600
# 10  136.820007  138.610001  135.029999  135.210007  134.817398   69672800
# 11  134.080002  136.250000  133.770004  135.270004  134.877228   58280400
# 12  135.279999  138.020004  134.220001  137.869995  137.469666   80223600
# 13  138.119995  143.320007  137.899994  141.110001  140.700256   81760300
# 14  140.309998  143.160004  140.300003  142.529999  142.116135   66435100
# 15  140.889999  142.429993  138.809998  141.860001  141.448074   65799300
# 16  143.169998  144.250000  141.899994  143.960007  143.541992   54105100
# 17  143.160004  147.229996  143.080002  145.929993  145.506256   70555800
# 18  144.960007  145.550003  142.850006  143.000000  142.584778   64015300
# 19  142.699997  144.339996  142.279999  144.289993  143.871017   65874500
#
#    sentiment  score
# 0   negative  0.513
# 1   positive  0.796
# 2    neutral  0.840
# 3    neutral  0.773
# 4   negative  0.916
# 5    neutral  0.873
# 6   negative  0.940
# 7   negative  0.967
# 8   negative  0.963
# 9   negative  0.659
# 10  positive  0.944
# 11   neutral  0.867
# 12   neutral  0.951
# 13  positive  0.897
# 14   neutral  0.510
# 15  positive  0.409
# 16   neutral  0.859
# 17   neutral  0.888
# 18   neutral  0.827
# 19   neutral  0.901

# %%
def modify_scores(row):
    if row['sentiment'] == 'neutral':
        return 0
    elif row['sentiment'] == 'negative':
        return 0 - row['score']
    else:
        return row['score']

# Apply the modify_scores function to the DataFrame
stocks_sentiment['score'] = stocks_sentiment.apply(modify_scores, axis=1)

# %%
stocks_sentiment.to_csv('finbert_stocks_output.csv', index=False)
